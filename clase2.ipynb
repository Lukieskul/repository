# %% [markdown]
# <a href="https://colab.research.google.com/github/Lukieskul/repository/blob/main/clase2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data **Wrangling**

# %%
path1 = 'https://raw.githubusercontent.com/tec03/Datasets/main/datasets/Cartwheeldata.csv'

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(path1)
df.head()
# Out:
#    ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0   1   56      F            1       Y             1    62.0      61.0
# 1   2   26      F            1       Y             1    62.0      60.0
# 2   3   33      F            1       Y             1    66.0      64.0
# 3   4   39      F            1       N             0    64.0      63.0
# 4   5   27      M            2       N             0    73.0      75.0
#
#    CWDistance Complete  CompleteGroup  Score
# 0          79        Y              1      7
# 1          70        Y              1      8
# 2          85        Y              1      0
# 3          87        Y              1     10
# 4          72        N              0      4

# %%
df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'GenderGroup', 'Glasses', 'GlassesGroup',
#        'Height', 'Wingspan', 'CWDistance', 'Complete', 'CompleteGroup',
#        'Score'],
#       dtype='object')

# %%
cols=df.columns

# %%
cols
# Out:
# Index(['ID', 'Age', 'Gender', 'GenderGroup', 'Glasses', 'GlassesGroup',
#        'Height', 'Wingspan', 'CWDistance', 'Complete', 'CompleteGroup',
#        'Score'],
#       dtype='object')

# %%
type(cols)
# Out:
# pandas.core.indexes.base.Index

# %%
df['Height']
# Out:
# 0     62.00
# 1     62.00
# 2     66.00
# 3     64.00
# 4     73.00
# 5     75.00
# 6     75.00
# 7     65.00
# 8     74.00
# 9     63.00
# 10    69.50
# 11    62.75
# 12    65.00
# 13    61.50
# 14    73.00
# 15    71.00
# 16    61.50
# 17    66.00
# 18    70.00
# 19    68.00
# 20    69.00
# 21    71.00
# 22    70.00
# 23    69.00
# 24    65.00
# Name: Height, dtype: float64

# %%
df.Height
# Out:
# 0     62.00
# 1     62.00
# 2     66.00
# 3     64.00
# 4     73.00
# 5     75.00
# 6     75.00
# 7     65.00
# 8     74.00
# 9     63.00
# 10    69.50
# 11    62.75
# 12    65.00
# 13    61.50
# 14    73.00
# 15    71.00
# 16    61.50
# 17    66.00
# 18    70.00
# 19    68.00
# 20    69.00
# 21    71.00
# 22    70.00
# 23    69.00
# 24    65.00
# Name: Height, dtype: float64

# %%
df[['Height', 'Age']]
# Out:
#     Height  Age
# 0    62.00   56
# 1    62.00   26
# 2    66.00   33
# 3    64.00   39
# 4    73.00   27
# 5    75.00   24
# 6    75.00   28
# 7    65.00   22
# 8    74.00   29
# 9    63.00   33
# 10   69.50   30
# 11   62.75   28
# 12   65.00   25
# 13   61.50   23
# 14   73.00   31
# 15   71.00   26
# 16   61.50   26
# 17   66.00   27
# 18   70.00   23
# 19   68.00   24
# 20   69.00   23
# 21   71.00   29
# 22   70.00   25
# 23   69.00   26
# 24   65.00   23

# %%
favs= ['Height', 'Age', 'Gender', 'Wingspan','Glasses','CWDistance']
ndf = df[favs]
ndf.head()
# Out:
#    Height  Age Gender  Wingspan Glasses  CWDistance
# 0    62.0   56      F      61.0       Y          79
# 1    62.0   26      F      60.0       Y          70
# 2    66.0   33      F      64.0       Y          85
# 3    64.0   39      F      63.0       N          87
# 4    73.0   27      M      75.0       N          72

# %%
df [['Height']]
# Out:
#     Height
# 0    62.00
# 1    62.00
# 2    66.00
# 3    64.00
# 4    73.00
# 5    75.00
# 6    75.00
# 7    65.00
# 8    74.00
# 9    63.00
# 10   69.50
# 11   62.75
# 12   65.00
# 13   61.50
# 14   73.00
# 15   71.00
# 16   61.50
# 17   66.00
# 18   70.00
# 19   68.00
# 20   69.00
# 21   71.00
# 22   70.00
# 23   69.00
# 24   65.00

# %%
type(df[['Height']])
# Out:
# pandas.core.frame.DataFrame

# %%
df ['Height']
# Out:
# 0     62.00
# 1     62.00
# 2     66.00
# 3     64.00
# 4     73.00
# 5     75.00
# 6     75.00
# 7     65.00
# 8     74.00
# 9     63.00
# 10    69.50
# 11    62.75
# 12    65.00
# 13    61.50
# 14    73.00
# 15    71.00
# 16    61.50
# 17    66.00
# 18    70.00
# 19    68.00
# 20    69.00
# 21    71.00
# 22    70.00
# 23    69.00
# 24    65.00
# Name: Height, dtype: float64

# %%
type(df['Height'])
# Out:
# pandas.core.series.Series

# %%
ndf.describe()
# Out:
#           Height        Age   Wingspan  CWDistance
# count  25.000000  25.000000  25.000000   25.000000
# mean   67.650000  28.240000  66.260000   82.480000
# std     4.431187   6.989754   5.492647   15.058552
# min    61.500000  22.000000  57.500000   63.000000
# 25%    64.000000  24.000000  62.000000   70.000000
# 50%    68.000000  26.000000  66.000000   81.000000
# 75%    71.000000  29.000000  71.000000   92.000000
# max    75.000000  56.000000  76.000000  115.000000

# %%
ndf.Glasses.unique()
# Out:
# array(['Y', 'N'], dtype=object)

# %%
ndf.Gender.value_counts()
# Out:
# Gender
# M    13
# F    12
# Name: count, dtype: int64

# %%
df.groupby(['Gender','Glasses']).size()
# Out:
# Gender  Glasses
# F       N          4
#         Y          8
# M       N          7
#         Y          6
# dtype: int64

# %%
favsGG=['Glasses','Gender']

# %%
ndf.groupby(favsGG).size()
# Out:
# Glasses  Gender
# N        F         4
#          M         7
# Y        F         8
#          M         6
# dtype: int64
